# %% [markdown]
# <a href="https://colab.research.google.com/github/its-zain-ul-abideen/Aritificial-Intelligence/blob/main/panda_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NOTE: I could not find the csv file online so i made my own csv file
# !rm Resumes.csv
from google.colab import files
uploaded = files.upload()

import pandas as pd
df = pd.read_csv('Resumes.csv')
print(df.to_string()) 

print("\n\n------------------------------------------- Cleaning ----------------------------------------------\n\n")

df.drop_duplicates(inplace = True) # clearing dublicate records or rows
df.dropna(inplace = True) # remove candidates with missing attributes
df.loc[10, 'Phone'] = "(555) 555-6123" # manually correcting wrong data
df = df.drop_duplicates(subset=["Email"], keep=False)   # clear dublicate emails

print(df.to_string())
# Out:
# rm: cannot remove 'Resumes.csv': No such file or directory
#      <input type="file" id="files-fdbd9bb0-08a7-493a-8c34-5e90d4f82a00" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fdbd9bb0-08a7-493a-8c34-5e90d4f82a00">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %% [markdown]
# _____________________________________________________________________________
# #                                    END
