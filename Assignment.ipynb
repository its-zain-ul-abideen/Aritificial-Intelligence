# %% [markdown]
# <a href="https://colab.research.google.com/github/its-zain-ul-abideen/Aritificial-Intelligence/blob/main/Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Name: Zain Ul abideen**
#
# **Registration: FA20-BSE-059**
#
# **Activity 1**: Use loops to accept 5 values from user and store them in a list. Display all the values (objects) of the list.

# %%
list1=[]
list2=[]
list3 = []
len= int(input("Enter the length of list1: "))
for i in range(len):
  list1.append(int(input("Enter value for list1: ")))
  list2.append(int(input("Enter value for list2: ")))
list3 = list1+list2
list3.sort()
print(list3)
# Out:
# Enter the length of list1: 2
# Enter value for list1: 34
# Enter value for list2: 53
# Enter value for list1: 12
# Enter value for list2: 6
# [6, 12, 34, 53]

# %% [markdown]
# **Activity 2**: Repeat the above code by accepting 5 integer values from user. Store these values in a list and display the sum of given values.

# %%
list=[]
len= int(input("Enter the length of list: "))
for i in range(len):
  list.append(int(input("Enter value for list: ")))
print(max(list))
print(min(list))
# Out:
# Enter the length of list: 5
# Enter value for list: 12
# Enter value for list: 43
# Enter value for list: 52
# Enter value for list: 51
# Enter value for list: 32
# 52
# 12

# %% [markdown]
# **Activity 3:**

# %%
import math
h = 0.001
x = -round(math.pi,3)

x_positive = round(math.pi,3)

while x != x_positive:
  for i in range(3):
    print(f'\n\n when h = {h} and x = {x}')
    eq_1 = math.cos(x)
    eq_2 = (math.sin(x+h)-math.sin(x))/h
    print(f'cos(x) = {eq_1}')
    print(f'(sin(x+h)-sin(x))/h = {eq_2} ')
    if(round(eq_1) == round(eq_2)):
      print("Equal")
    else:
      print("Not equal")
    h = h*10
  h = 0.001
  x += 0.001
  x = round(x,3)
# Out:
# Streaming output truncated to the last 5000 lines.
# (sin(x+h)-sin(x))/h = -0.9618547969681979
# Equal
#
#
#  when h = 0.01 and x = 2.864
# cos(x) = -0.9617179366377046
# (sin(x+h)-sin(x))/h = -0.9630721029504796
# Equal
#
#
#  when h = 0.1 and x = 2.864
# cos(x) = -0.9617179366377046
# (sin(x+h)-sin(x))/h = -0.9738065229033285
# Equal
#
#
#  when h = 0.001 and x = 2.865
# cos(x) = -0.9619914969897584
# (sin(x+h)-sin(x))/h = -0.9621278763473073
# Equal
#
#
#  when h = 0.01 and x = 2.865
# cos(x) = -0.9619914969897584
# (sin(x+h)-sin(x))/h = -0.9633408495093088
# Equal
#
#
#  when h = 0.1 and x = 2.865
# cos(x) = -0.9619914969897584
# (sin(x+h)-sin(x))/h = -0.9740315748734526
# Equal
#
#
#  when h = 0.001 and x = 2.866
# cos(x) = -0.9622640953503951
# (sin(x+h)-sin(x))/h = -0.962399993598595
# Equal
#
#
#  when h = 0.01 and x = 2.866
# cos(x) = -0.9622640953503951
# (sin(x+h)-sin(x))/h = -0.9636086327273696
# Equal
#
#
#  when h = 0.1 and x = 2.866
# cos(x) = -0.9622640953503951
# ...
